# %% [markdown]
# # Week 2 EDA Notebook
# Run `python ../run_week2.py` first, then inspect the generated outputs here.

# %%
from pathlib import Path
import pandas as pd

CWD = Path.cwd().resolve()
ROOT = CWD if (CWD / 'data').exists() else CWD.parent
features = pd.read_csv(ROOT / 'data/processed/sector_features.csv', parse_dates=['Date'])
features.head()

# %%
summary = pd.read_csv(ROOT/'results/tables/sector_return_summary.csv')
summary

# %%
correlation = pd.read_csv(ROOT/'results/tables/sector_correlation.csv', index_col=0)
correlation

# %%
latest = pd.read_csv(ROOT/'results/tables/latest_feature_snapshot.csv')
latest

# %% [markdown]
# Figures are stored in `results/figures/`. The generated report is `docs/early_insights_report.md`.
